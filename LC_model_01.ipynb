# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
from jugaad_data.nse import stock_df
from sklearn.preprocessing import MinMaxScaler

# %%
df = stock_df(symbol="SBIN", from_date=date(2015,1,1),to_date=date(2020,1,30), series="EQ")

# %%
df.head()
# Out:
#         DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0 2020-01-30     EQ  316.75  316.75  305.65       316.45  310.00  310.70
# 1 2020-01-29     EQ  317.85  319.70  315.55       315.10  316.95  316.45
# 2 2020-01-28     EQ  317.95  320.00  311.05       316.20  316.40  315.10
# 3 2020-01-27     EQ  320.90  322.00  315.80       324.05  316.40  316.20
# 4 2020-01-24     EQ  323.50  327.30  321.15       323.20  324.30  324.05
#
#      VWAP  52W H   52W L    VOLUME         VALUE  NO OF TRADES SYMBOL
# 0  311.18  373.8  244.35  35802330  1.114102e+10        227687   SBIN
# 1  317.75  373.8  244.35  23914114  7.598704e+09        143297   SBIN
# 2  316.67  373.8  244.35  26488426  8.388015e+09        173879   SBIN
# 3  318.82  373.8  244.35  23309355  7.431558e+09        148768   SBIN
# 4  325.15  373.8  244.35  22706879  7.383247e+09        146667   SBIN

# %%
df.shape
# Out:
# (1251, 15)

# %%
data = df[['DATE', 'SYMBOL', 'OPEN', 'PREV. CLOSE', 'LOW', 'HIGH', 'VOLUME']]

# %%
data.head()
# Out:
#         DATE SYMBOL    OPEN  PREV. CLOSE     LOW    HIGH    VOLUME
# 0 2020-01-30   SBIN  316.75       316.45  305.65  316.75  35802330
# 1 2020-01-29   SBIN  317.85       315.10  315.55  319.70  23914114
# 2 2020-01-28   SBIN  317.95       316.20  311.05  320.00  26488426
# 3 2020-01-27   SBIN  320.90       324.05  315.80  322.00  23309355
# 4 2020-01-24   SBIN  323.50       323.20  321.15  327.30  22706879

# %%
data.shape
# Out:
# (1251, 7)

# %%
data['SYMBOL'].value_counts()
# Out:
# SYMBOL
# SBIN    1251
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1251 entries, 0 to 1250
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         1251 non-null   datetime64[ns]
#  1   SYMBOL       1251 non-null   object
#  2   OPEN         1251 non-null   float64
#  3   PREV. CLOSE  1251 non-null   float64
#  4   LOW          1251 non-null   float64
#  5   HIGH         1251 non-null   float64
#  6   VOLUME       1251 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 68.5+ KB

# %%
data.describe()
# Out:
#                                 DATE         OPEN  PREV. CLOSE          LOW  \
# count                           1251  1251.000000  1251.000000  1251.000000
# mean   2017-07-15 00:10:21.582733824   272.440568   271.862110   268.413589
# min              2015-01-01 00:00:00   155.000000   151.800000   148.250000
# 25%              2016-04-09 12:00:00   252.000000   251.275000   248.525000
# 50%              2017-07-14 00:00:00   274.000000   273.300000   269.900000
# 75%              2018-10-18 00:00:00   297.000000   297.350000   293.275000
# max              2020-01-30 00:00:00   371.950000   372.400000   366.200000
# std                              NaN    40.561452    40.513654    40.123427
#
#               HIGH        VOLUME
# count  1251.000000  1.251000e+03
# mean    275.795004  2.081010e+07
# min     157.650000  2.061681e+06
# 25%     255.325000  1.263975e+07
# 50%     277.000000  1.701312e+07
# 75%     302.000000  2.394051e+07
# max     373.800000  2.626771e+08
# std      40.897982  1.484999e+07

# %%
data.isnull().sum()
# Out:
# DATE           0
# SYMBOL         0
# OPEN           0
# PREV. CLOSE    0
# LOW            0
# HIGH           0
# VOLUME         0
# dtype: int64

# %%
len(data['DATE'].unique())
# Out:
# 1251

# %%
def plotter(code):
    global closing_stock , opening_stock
    
    #Opening Price Plot
    
    plt.subplot(2,1,1)
    company = df[df['SYMBOL'] == code]
    company = company['OPEN'].values.astype('float32')
    company = company.reshape(-1,1)
    opening_stock = company
    
    plt.grid(True)
    plt.xlabel('Time')
    plt.ylabel(code + '  Open stock prices')
    plt.title('Price X Time' + code)
    plt.plot(company,'g')
    plt.show()
    
    #Closing Price Plot
    plt.subplot(2,1,2)
    company_close = df[df['SYMBOL'] == code]
    company_close = company_close['CLOSE'].values.astype('float32')
    company_close = company_close.reshape(-1,1)
    closing_stock = company_close
    
    plt.grid(True)
    plt.xlabel('Time')
    plt.ylabel(code + '  Close Stock Prices')
    plt.title('Price X Time for  '+ code)
    plt.plot(company_close,'b')
    plt.show()

# %%
plotter('SBIN')

# %%
stocks = np.array(data[data['SYMBOL'].isin(['SBIN'])]['PREV. CLOSE'])

stocks
# Out:
# array([316.45, 315.1 , 316.2 , ..., 315.25, 314.  , 311.85])

# %%
stocks = stocks.reshape(-1,1)
stocks.shape
# Out:
# (1251, 1)

# %%
mms = MinMaxScaler(feature_range=(0,1))
stocks = mms.fit_transform(stocks)
stocks
# Out:
# array([[0.74637353],
#        [0.74025385],
#        [0.74524025],
#        ...,
#        [0.74093382],
#        [0.73526745],
#        [0.72552131]])

# %%
train_len = int(len(stocks) * 0.8)
train_len
# Out:
# 1000

# %%
test_len = len(stocks) - train_len
test_len
# Out:
# 251

# %%
train = stocks[0:train_len]
print(train.shape)
# Out:
# (1000, 1)

# %%
test = stocks[train_len:]
print(test.shape)
# Out:
# (251, 1)

# %%
def process_data(data , n_features):
    dataX , dataY = [],[]
    for i in range(len(data) - n_features):
        a = data[i : (i + n_features),0]
        dataX.append(a)
        dataY.append(data[i + n_features,0 ])
    return np.array(dataX) , np.array(dataY)

# %%
n_features = 5
trainX , trainY = process_data(train , n_features)
print(trainX.shape , trainY.shape)
# Out:
# (995, 5) (995,)

# %%
testX , testY = process_data(test , n_features)
print(testX.shape , testY.shape)
# Out:
# (246, 5) (246,)

# %%
stocksX, stocksY = process_data(stocks, n_features)
print (stocksX.shape , stocksY.shape)
# Out:
# (1246, 5) (1246,)

# %%
trainX[:10]
# Out:
# array([[0.74637353, 0.74025385, 0.74524025, 0.78082502, 0.77697189],
#        [0.74025385, 0.74524025, 0.78082502, 0.77697189, 0.7450136 ],
#        [0.74524025, 0.78082502, 0.77697189, 0.7450136 , 0.73390752],
#        [0.78082502, 0.77697189, 0.7450136 , 0.73390752, 0.73526745],
#        [0.77697189, 0.7450136 , 0.73390752, 0.73526745, 0.75339982],
#        [0.7450136 , 0.73390752, 0.73526745, 0.75339982, 0.7774252 ],
#        [0.73390752, 0.73526745, 0.75339982, 0.7774252 , 0.78173164],
#        [0.73526745, 0.75339982, 0.7774252 , 0.78173164, 0.79873073],
#        [0.75339982, 0.7774252 , 0.78173164, 0.79873073, 0.81119674],
#        [0.7774252 , 0.78173164, 0.79873073, 0.81119674, 0.81799637]])

# %%
print(trainX.shape)
trainX = trainX.reshape(trainX.shape[0] , 1 , trainX.shape[1])
trainX.shape
# Out:
# (995, 5)
# (995, 1, 5)

# %%
testX = testX.reshape(testX.shape[0] , 1 , testX.shape[1])
testX.shape
# Out:
# (246, 1, 5)

# %%
stocksX= stocksX.reshape(stocksX.shape[0] , 1 ,stocksX.shape[1])
display (stocksX.shape)
# Out:
# (1246, 1, 5)

# %% [markdown]
# # BUILDING MODEL

# %%
from tensorflow.keras.layers import LSTM , GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , BatchNormalization , Dropout , Activation
from tensorflow.keras.optimizers import Adam , SGD , RMSprop
from sklearn.metrics import mean_squared_error
import math

# %%
filepath = 'PRJ Stock Price Prediction\stock_weights1.hdf5'
from tensorflow.keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
lr_reduce = ReduceLROnPlateau(monitor = 'val_loss' , factor = 0.1 , epsilon = 0.0001 , patience = 1 , verbose = 1)
checkpoint = ModelCheckpoint(filepath , monitor = 'val_loss' , varbose = 1 , save_best_only = True , mode = 'max')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
model = Sequential()

# %%
model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences = True))
model.add(Dropout(0.4))
model.add(LSTM(256))
model.add(Dropout(0.4))
model.add(Dense(64 , activation = 'relu'))
model.add(Dense(1))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 256)            201984
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  lstm (LSTM)                 (None, 256)               525312
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 743,809
# Trainable params: 743,809
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile( loss = 'mean_squared_error' , optimizer = Adam(learning_rate=0.0005) , metrics = ['mean_squared_error'])

# %%
history = model.fit(trainX , trainY , epochs = 50 , callbacks = [checkpoint , lr_reduce] , validation_data = (testX , testY))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 8s 123ms/step - loss: 0.1005 - mean_squared_error: 0.1005 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - lr: 5.0000e-04
# Epoch 2/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 2: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 32/32 [==============================] - 3s 100ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - lr: 5.0000e-04
# Epoch 3/100
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 5.0000e-05
# Epoch 4/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 32/32 [==============================] - 3s 105ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-05
# Epoch 5/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-06
# Epoch 6/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-07
# Epoch 7/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 32/32 [==============================] - 3s 101ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-08
# Epoch 8/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 32/32 [==============================] - 3s 107ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-09
# Epoch 9/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-10
# Epoch 10/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 32/32 [==============================] - 2s 48ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-11
# Epoch 11/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 32/32 [==============================] - 2s 61ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-12
# Epoch 12/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 32/32 [==============================] - 2s 51ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-13
# Epoch 13/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 32/32 [==============================] - 3s 78ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-14
# Epoch 14/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 32/32 [==============================] - 3s 78ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-15
# Epoch 15/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 32/32 [==============================] - 2s 72ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-16
# Epoch 16/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 32/32 [==============================] - 2s 77ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-17
# Epoch 17/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 32/32 [==============================] - 3s 83ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-18
# Epoch 18/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 32/32 [==============================] - 2s 77ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-19
# Epoch 19/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 32/32 [==============================] - 2s 45ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-20
# Epoch 20/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-21
# Epoch 21/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 32/32 [==============================] - 2s 61ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-22
# Epoch 22/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-23
# Epoch 23/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-24
# Epoch 24/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-25
# Epoch 25/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-26
# Epoch 26/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# 32/32 [==============================] - 3s 81ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-27
# Epoch 27/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# 32/32 [==============================] - 3s 76ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-28
# Epoch 28/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-29
# Epoch 29/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# 32/32 [==============================] - 2s 54ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-30
# Epoch 30/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# 32/32 [==============================] - 3s 99ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-31
# Epoch 31/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# 32/32 [==============================] - 3s 99ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-32
# Epoch 32/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# 32/32 [==============================] - 3s 88ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-33
# Epoch 33/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 33: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-34
# Epoch 34/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# 32/32 [==============================] - 3s 83ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-35
# Epoch 35/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# 32/32 [==============================] - 2s 70ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-36
# Epoch 36/100
# 26/32 [=======================>......] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-37
# Epoch 37/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# 32/32 [==============================] - 2s 43ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-38
# Epoch 38/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# 32/32 [==============================] - 2s 52ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-39
# Epoch 39/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-40
# Epoch 40/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0000e-41
# Epoch 41/100
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 4.9998e-42
# Epoch 42/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 42: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0026e-43
# Epoch 43/100
# 31/32 [============================>.] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 43: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# 32/32 [==============================] - 2s 43ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.0447e-44
# Epoch 44/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.6052e-45
# Epoch 45/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 46/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 47/100
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 48/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 49/100
# 32/32 [==============================] - 3s 95ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 50/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 51/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 52/100
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 53/100
# 32/32 [==============================] - 3s 106ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 54/100
# 32/32 [==============================] - 3s 97ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 55/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 56/100
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 57/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 58/100
# 32/32 [==============================] - 3s 96ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 59/100
# 32/32 [==============================] - 3s 109ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 60/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 61/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 62/100
# 32/32 [==============================] - 4s 103ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 63/100
# 32/32 [==============================] - 3s 94ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 64/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 65/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 66/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 67/100
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 68/100
# 32/32 [==============================] - 1s 28ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 69/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 70/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 71/100
# 32/32 [==============================] - 3s 96ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 72/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 73/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 74/100
# 32/32 [==============================] - 3s 104ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 75/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 76/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 77/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 78/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 79/100
# 32/32 [==============================] - 3s 99ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 80/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 81/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 82/100
# 32/32 [==============================] - 3s 96ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 83/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 84/100
# 32/32 [==============================] - 4s 117ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 85/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 86/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 87/100
# 32/32 [==============================] - 2s 50ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 88/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 89/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 90/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 91/100
# 32/32 [==============================] - 3s 99ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 92/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 93/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 94/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 95/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 96/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 97/100
# 32/32 [==============================] - 4s 109ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 98/100
# 32/32 [==============================] - 4s 121ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 99/100
# 32/32 [==============================] - 3s 94ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00
# Epoch 100/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 0.0000e+00

# %%
test_pred = model.predict(testX)
test_pred[:10]
# Out:
# 8/8 [==============================] - 1s 6ms/step
# array([[0.362136  ],
#        [0.36858457],
#        [0.37567002],
#        [0.38298726],
#        [0.3826534 ],
#        [0.38639182],
#        [0.38835615],
#        [0.39033642],
#        [0.38803205],
#        [0.39068466]], dtype=float32)

# %%
test_pred = mms.inverse_transform(test_pred)
test_pred[:10]
# Out:
# array([[231.68721],
#        [233.10976],
#        [234.6728 ],
#        [236.287  ],
#        [236.21333],
#        [237.03802],
#        [237.47136],
#        [237.90822],
#        [237.39986],
#        [237.98503]], dtype=float32)

# %%
testY[:10]
# Out:
# array([0.33544878, 0.3463282 , 0.34950136, 0.3467815 , 0.35290118,
#        0.34700816, 0.35652765, 0.33862194, 0.35856754, 0.34224841])

# %%
testY = testY.reshape(testY.shape[0] , 1)
testY[:10]
# Out:
# array([[0.33544878],
#        [0.3463282 ],
#        [0.34950136],
#        [0.3467815 ],
#        [0.35290118],
#        [0.34700816],
#        [0.35652765],
#        [0.33862194],
#        [0.35856754],
#        [0.34224841]])

# %%
testY = mms.inverse_transform(testY)
testY[:10]
# Out:
# array([[225.8 ],
#        [228.2 ],
#        [228.9 ],
#        [228.3 ],
#        [229.65],
#        [228.35],
#        [230.45],
#        [226.5 ],
#        [230.9 ],
#        [227.3 ]])

# %%
from sklearn.metrics import r2_score
score = r2_score(testY , test_pred)
score
# Out:
# 0.8730664881595724

# %%
plt.plot(testY , 'b')
plt.plot(test_pred , 'r')
plt.xlabel('Time')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
train_pred = model.predict(trainX)
train_pred = mms.inverse_transform(train_pred)
trainY = trainY.reshape(trainY.shape[0] , 1)
trainY = mms.inverse_transform(trainY)
print ('Display Accuracy Training Data')
display (r2_score(trainY,train_pred))
# Out:
# 32/32 [==============================] - 0s 8ms/step
# Display Accuracy Training Data
# 0.9301616338060609

# %%
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(trainY  , 'b')
plt.plot(train_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
stocks_pred = model.predict(stocksX)
stocks_pred = mms.inverse_transform(stocks_pred)
stocksY = stocksY.reshape(stocksY.shape[0] , 1)
stocksY = mms.inverse_transform(stocksY)
print ('Display Accuracy Training Data')
display (r2_score(stocksY,stocks_pred))
# Out:
# 39/39 [==============================] - 0s 8ms/step
# Display Accuracy Training Data
# 0.9262954541161446

# %%
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(stocksY  , 'b')
plt.plot(stocks_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Accuracy of the model with time')
plt.grid(True)
plt.show()

# %%
final_score = r2_score(stocksY , stocks_pred)
final_score
# Out:
# 0.9262954541161446

# %%
trainY[-1]
# Out:
# array([209.55])

# %%
train_pred[-1]
# Out:
# array([216.03954], dtype=float32)
